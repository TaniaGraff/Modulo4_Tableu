# %%
#Importo librerías
import pandas as pd
import numpy as np

import os
import sys
sys.path.append("../")

import warnings
warnings.filterwarnings("ignore")

# %%
pip install xlrd
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
df_2023 = pd.read_excel('../ETL_limpieza_y_transformacion_archivos/data/input_data/DataForFigure21WHR2023.xls')
df_2023
# Out:
#          Country name  Ladder score  Standard error of ladder score  \
# 0             Finland        7.8042                        0.036162
# 1             Denmark        7.5864                        0.041028
# 2             Iceland        7.5296                        0.048612
# 3              Israel        7.4729                        0.031609
# 4         Netherlands        7.4030                        0.029294
# ..                ...           ...                             ...
# 132  Congo (Kinshasa)        3.2072                        0.095369
# 133          Zimbabwe        3.2035                        0.060865
# 134      Sierra Leone        3.1376                        0.082441
# 135           Lebanon        2.3922                        0.044495
# 136       Afghanistan        1.8590                        0.032506
#
#      upperwhisker  lowerwhisker  Logged GDP per capita  Social support  \
# 0        7.875078      7.733322              10.792010        0.968770
# ...

# %%
df_historico= pd.read_excel('../ETL_limpieza_y_transformacion_archivos/data/input_data/DataForTable21WHR2023.xls')
df_historico
# Out:
#      Country name  year  Life Ladder  Log GDP per capita  Social support  \
# 0     Afghanistan  2008     3.723590            7.350416        0.450662
# 1     Afghanistan  2009     4.401778            7.508646        0.552308
# 2     Afghanistan  2010     4.758381            7.613900        0.539075
# 3     Afghanistan  2011     3.831719            7.581259        0.521104
# 4     Afghanistan  2012     3.782938            7.660506        0.520637
# ...           ...   ...          ...                 ...             ...
# 2194     Zimbabwe  2018     3.616480            7.783066        0.775388
# 2195     Zimbabwe  2019     2.693523            7.697755        0.759162
# 2196     Zimbabwe  2020     3.159802            7.596050        0.717243
# 2197     Zimbabwe  2021     3.154578            7.656878        0.685151
# 2198     Zimbabwe  2022     3.296220            7.670123        0.666172
#
#       Healthy life expectancy at birth  Freedom to make life choices  \
# ...

# %%
df_Finlandia_historico = df_historico[df_historico['Country name'] == 'Finland']
df_Finlandia_historico
# Out:
#     Country name  year  Life Ladder  Log GDP per capita  Social support  \
# 623      Finland  2006     7.672449           10.745317        0.964563
# 624      Finland  2008     7.670627           10.795855        0.951340
# 625      Finland  2010     7.393264           10.733668        0.935481
# 626      Finland  2011     7.354225           10.754190        0.937857
# 627      Finland  2012     7.420209           10.735358        0.927739
# 628      Finland  2013     7.444636           10.721693        0.940869
# 629      Finland  2014     7.384571           10.713902        0.952017
# 630      Finland  2015     7.447926           10.716029        0.947801
# 631      Finland  2016     7.659843           10.740882        0.953940
# 632      Finland  2017     7.788252           10.769960        0.963826
# 633      Finland  2018     7.858107           10.779966        0.962155
# 634      Finland  2019     7.780348           10.791038        0.937416
# ...

# %%
df_historico.isnull().sum()
# Out:
# Country name                          0
# year                                  0
# Life Ladder                           0
# Log GDP per capita                   20
# Social support                       13
# Healthy life expectancy at birth     54
# Freedom to make life choices         33
# Generosity                           73
# Perceptions of corruption           116
# Positive affect                      24
# Negative affect                      16
# dtype: int64

# %%
df_2023.isnull().sum()
# Out:
# Country name                                  0
# Ladder score                                  0
# Standard error of ladder score                0
# upperwhisker                                  0
# lowerwhisker                                  0
# Logged GDP per capita                         0
# Social support                                0
# Healthy life expectancy                       1
# Freedom to make life choices                  0
# Generosity                                    0
# Perceptions of corruption                     0
# Ladder score in Dystopia                      0
# Explained by: Log GDP per capita              0
# Explained by: Social support                  0
# Explained by: Healthy life expectancy         1
# Explained by: Freedom to make life choices    0
# Explained by: Generosity                      0
# Explained by: Perceptions of corruption       0
# Dystopia + residual                           1
# dtype: int64

# %%
df= pd.read_csv('../ETL_limpieza_y_transformacion_archivos/data/output_data/ranking_2023.csv')
df
# Out:
#          Country_Name  Ladder_Score  Standard_Error_Of_Ladder_Score  \
# 0             Finland        7.8042                        0.036162
# 1             Denmark        7.5864                        0.041028
# 2             Iceland        7.5296                        0.048612
# 3              Israel        7.4729                        0.031609
# 4         Netherlands        7.4030                        0.029294
# ..                ...           ...                             ...
# 132  Congo (Kinshasa)        3.2072                        0.095369
# 133          Zimbabwe        3.2035                        0.060865
# 134      Sierra Leone        3.1376                        0.082441
# 135           Lebanon        2.3922                        0.044495
# 136       Afghanistan        1.8590                        0.032506
#
#      Upperwhisker  Lowerwhisker  Logged_Gdp_Per_Capita  Social_Support  \
# 0        7.875078      7.733322              10.792010        0.968770
# ...
